# %%
import sys
#sys.path.append("/home/markdj/repos/Polesia-Landcover/data_stack_testing/")
sys.path.append("C:/Users/tpfdo/OneDrive/Documents/GitHub/Polesia-Landcover/data_stack_testing/")
import ee
from geemap import geemap
from data_stack_tools_v1 import create_data_stack, create_data_stack_v2, fetch_sentinel1_v2, fetch_sentinel2_v2, map_topography, fetch_sentinel2_v3
ee.Initialize()

# %% [markdown]
# variables - could all easily be added to a config file somewhere

# %%
fp_train_ext = "/home/markdj/Dropbox/artio/polesia/val/Vegetation_extent_rough.shp"
#fp_train_ext = "D:/tpfdo/Documents/Artio_drive/Projects/Polesia/Project_area.shp"

aoi = geemap.shp_to_ee(fp_train_ext)
start_date_list = ['2019-01-01', '2019-02-01', 
                   '2019-03-01', '2019-04-01', 
                   '2019-05-01', '2019-06-01', 
                   '2019-07-01', '2019-08-01',
                   '2019-09-01', '2019-10-01',
                   '2019-11-01', '2019-12-01']

s2_params = {
    'CLOUD_FILTER': 60,       # int, max cloud coverage (%) permitted in a scene
    'CLD_PRB_THRESH': 40,     # int, 's2cloudless' 'probability' band value > thresh = cloud
    'NIR_DRK_THRESH': 0.15,   # float, if Band 8 (NIR) < NIR_DRK_THRESH = possible shadow
    'CLD_PRJ_DIST': 1,        # int, max distnce [TODO: km or 100m?] from cloud edge for possible shadow 
    'BUFFER': 100             # int, distance (m) used to buffer cloud edges
}

# %% [markdown]
# get full data stack in one line...

# %%
stack = create_data_stack(aoi, start_date_list, s2_params)
# Out:
# fetch_sentinel1(): hello!
# fetch_sentinel1(): processing month 2019-01-01
# fetch_sentinel1(): processing month 2019-02-01
# fetch_sentinel1(): processing month 2019-03-01
# fetch_sentinel1(): processing month 2019-04-01
# fetch_sentinel1(): processing month 2019-05-01
# fetch_sentinel1(): processing month 2019-06-01
# fetch_sentinel1(): processing month 2019-07-01
# fetch_sentinel1(): processing month 2019-08-01
# fetch_sentinel1(): processing month 2019-09-01
# fetch_sentinel1(): processing month 2019-10-01
# fetch_sentinel1(): processing month 2019-11-01
# fetch_sentinel1(): processing month 2019-12-01
# fetch_sentinel1(): bye!
# fetch_sentinel2(): hello!
# fetch_sentinel2(): processing month 2019-01-01
# fetch_sentinel2(): processing month 2019-02-01
# fetch_sentinel2(): processing month 2019-03-01
# fetch_sentinel2(): processing month 2019-04-01
# fetch_sentinel2(): processing month 2019-05-01
# fetch_sentinel2(): processing month 2019-06-01
# fetch_sentinel2(): processing month 2019-07-01
# fetch_sentinel2(): processing month 2019-08-01
# fetch_sentinel2(): processing month 2019-09-01
# fetch_sentinel2(): processing month 2019-10-01
# fetch_sentinel2(): processing month 2019-11-01
# fetch_sentinel2(): processing month 2019-12-01
# fetch_sentinel2(): bye!
# fetch_topography(): hi!
# fetch_topography(): bye!

# %%
stack.getInfo()
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'S1_VV_2019-01',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-01',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-02',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-02',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-03',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-03',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-04',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-04',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-05',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-05',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-06',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-06',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-07',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-07',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-08',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-08',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-09',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-09',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-10',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-10',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-11',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-11',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VV_2019-12',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S1_VH_2019-12',
#    'data_type': {'type': 'PixelType', 'precision': 'double'},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-01',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-02',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-03',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-04',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-05',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-06',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-07',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-08',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-09',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B2_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B3_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B4_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B5_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B6_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B7_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B8A_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B11_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'S2_B12_2019-12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'double',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [2, 2],
#    'origin': [27, 51],
#    'crs': 'EPSG:4326',
#    'crs_transform': [1, 0, 0, 0, 1, 0]},
#   {'id': 'slope',
#    'data_type': {'type': 'PixelType',
#     'precision': 'float',
#     'min': 0,
#     'max': 90},
#    'crs': 'EPSG:4326',
#    'crs_transform': [0.0002777777777777778,
#     0,
#     -180.0001388888889,
#     0,
#     -0.0002777777777777778,
#     60.00013888888889]},
#   {'id': 'aspect',
#    'data_type': {'type': 'PixelType',
#     'precision': 'float',
#     'min': 0,
#     'max': 360},
#    'crs': 'EPSG:4326',
#    'crs_transform': [0.0002777777777777778,
#     0,
#     -180.0001388888889,
#     0,
#     -0.0002777777777777778,
#     60.00013888888889]}],
#  'properties': {'system:footprint': {'type': 'Polygon',
#    'coordinates': [[[27.390896512881636, 52.215894288509645],
#      [27.28375045749374, 52.17067849106585],
#      [27.217915678498112, 52.08718415794678],
#      [27.082028498028603, 52.0206605622657],
#      [27.09223557538949, 51.768417042850544],
#      [27.093075989215286, 51.762196363393066],
#      [27.195028318147536, 51.764056546432464],
#      [27.20097339223106, 51.66187841476993],
#      [27.91897226216094, 52.133628520066374],
#      [27.91314652191147, 52.10111889499595],
#      [27.682218191154206, 52.134441745723784],
#      [27.591872422079934, 52.14875866263611],
#      [27.483797463033895, 52.18048202114129],
#      [27.483797463033895, 52.18048202114129],
#      [27.390896512881636, 52.215894288509645]]]}}}

# %% [markdown]
# quick test...

# %%
lat=51.85
lon=27.8
Map = geemap.Map(center=(lat, lon), zoom=9)
Map.add_basemap('SATELLITE')
vis = {'min': -0.0,'max': 3000,'bands': [f'S2_B4_2019-04', f'S2_B3_2019-04', f'S2_B2_2019-04']}
Map.addLayer(stack, vis, f'S2_rgb_2019-04')
vis = {'min': -0.0,'max': 3000,'bands': [f'S2_B8_2019-04', f'S2_B4_2019-04', f'S2_B3_2019-04']}
Map.addLayer(stack, vis, f'S2_fcc_2019-04')
vis = {'min': -0.0,'max': 3000, 'bands': [f'S2_B8_2019-04']}
Map.addLayer(stack, vis, f'S2_B8_2019-04')
vis = {'min': -0.0,'max': 3000, 'bands': [f'S2_B12_2019-04']}
Map.addLayer(stack, vis, f'S2_B12_2019-04')
vis = {'min': -50,'max': 1, 'bands': [f'S1_VV_2019-04', f'S1_VH_2019-04', f'S1_VH_2019-04']}
Map.addLayer(stack, vis, f'S1_VV_VH_2019-04')
Map
# Out:
# Map(center=[51.85, 27.8], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children…

# %% [markdown]
# check topo derived layers

# %%
map_topography(stack)
# Out:
# Map(center=[51.85, 27.8], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children…

# %% [markdown]
# # Test V2 fetch functions
# * have to prescribe the start and end dates as below

# %%
# date_list replaces 'start_date_list'
date_list = [('2018-12-01', '2019-02-01'),('2019-05-01', '2019-05-31')]
date_list = [('2017-12-01', '2018-02-01')]  # this just generates a ~2 month composite


# ** note there is now a new S2BANDS entry here **

s2_params = {
    'CLOUD_FILTER': 60,       # int, max cloud coverage (%) permitted in a scene
    'CLD_PRB_THRESH': 40,     # int, 's2cloudless' 'probability' band value > thresh = cloud
    'NIR_DRK_THRESH': 0.15,   # float, if Band 8 (NIR) < NIR_DRK_THRESH = possible shadow
    'CLD_PRJ_DIST': 1,        # int, max distnce [TODO: km or 100m?] from cloud edge for possible shadow 
    'BUFFER': 100,             # int, distance (m) used to buffer cloud edges
    #'S2BANDS': ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12'] #list of str, which S2 bands to return?
    'S2BANDS': ['B2', 'B3', 'B4', 'B6', 'B8', 'B11'] #list of str, which S2 bands to return?
}

# %%
# the combined datastack in 1 line
stack = create_data_stack_v2(aoi, date_list, s2_params)

# or call the underlying S1 and S2 functions...
s2tmp = fetch_sentinel2_v2(aoi, date_list, s2_params)
s1tmp = fetch_sentinel1_v2(aoi, date_list)
# Out:
# fetch_sentinel1(): hello!
# fetch_sentinel1(): processing period: 2017-12-01 to 2018-02-01
# fetch_sentinel1(): bye!
# fetch_sentinel2(): hello!
# fetch_sentinel2(): processing period: 2017-12-01 to 2018-02-01
# fetch_sentinel2(): bye!
# fetch_topography(): hi!
# fetch_topography(): bye!
# Calculating min-max values for each band...
# Normalising all bands with min-max...
# Normalisation complete!
# Calculating indices...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     337   try:
# --> 338     return call.execute(num_retries=num_retries)
#     339   except googleapiclient.errors.HttpError as e:
#
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
#     908         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Image.select: Pattern 'S2_B8_2018-06-01_2018-06-30' did not match any bands.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-6-cbf24eb38dcf> in <module>
#       1 # the combined datastack in 1 line
# ----> 2 stack = create_data_stack_v2(aoi, date_list, s2_params)
#       3
#       4 # or call the underlying S1 and S2 functions...
#       5 s2tmp = fetch_sentinel2_v2(aoi, date_list, s2_params)
#
# ~/repos/Polesia-Landcover/data_stack_testing/data_stack_tools_v1.py in create_data_stack_v2(aoi, date_list, s2_params)
#     684
#     685     # Remove unwanted bands and bands that are now part of a index
# --> 686     nameOfBands = normed_combined_stack.bandNames().getInfo()
#     687     nameOfBands.remove('S2_B4_2018-04-01_2018-04-30')
#     688     nameOfBands.remove('S2_B8_2018-04-01_2018-04-30')
#
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/ee/computedobject.py in getInfo(self)
#      93       The object can evaluate to anything.
#      94     """
# ---> 95     return data.computeValue(self)
#      96
#      97   def encode(self, encoder):
#
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/ee/data.py in computeValue(obj)
#     701         body={'expression': serializer.encode(obj, for_cloud_api=True)},
#     702         project=_get_projects_path(),
# --> 703         prettyPrint=False))['result']
#     704   return send_('/value', ({'json': obj.serialize(), 'json_format': 'v2'}))
#     705
#
# ~/anaconda3/envs/polesia-lc/lib/python3.6/site-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     338     return call.execute(num_retries=num_retries)
#     339   except googleapiclient.errors.HttpError as e:
# --> 340     raise _translate_cloud_exception(e)
#     341
#     342
#
# EEException: Image.select: Pattern 'S2_B8_2018-06-01_2018-06-30' did not match any bands.

# %%
# of course, now i have changed band naming so the mapping functions are screwed.
# quick check..
# WTF is the weird striping in the S1 data? data gap?

#note: calling get.info() on everything is very useful!
s1bands = s1tmp.bandNames().getInfo()
s2bands = s2tmp.bandNames().getInfo()
#print(s2bands)

lat=51.85
lon=27.8
Map = geemap.Map(center=(lat, lon), zoom=9)
Map.add_basemap('SATELLITE')

vis = {'min': -50,'max': 1, 'bands': [s1bands[0],s1bands[1],s1bands[1]]}
Map.addLayer(s1tmp, vis, f'S1')
vis = {'min': -1,'max': 3000, 'bands': [s2bands[2],s2bands[1],s2bands[0]]}
Map.addLayer(s2tmp, vis, f'S2')
Map

# %% [markdown]
# ### test v3 s2 func

# %%
fp_train_ext = "/home/markdj/Dropbox/artio/polesia/val/tiny_roi.shp"
aoi = geemap.shp_to_ee(fp_train_ext)

start_date_list = [('2018-01-01','2018-01-31')]
s2_stack18fill = fetch_sentinel2_v3(aoi, start_date_list, s2_params)

start_date_list = [('2019-01-01','2019-01-31')]
s2_stack19fill = fetch_sentinel2_v3(aoi, start_date_list, s2_params)
# Out:
# fetch_sentinel2(): hello!
# fetch_sentinel2(): processing period: 2018-01-01 to 2018-01-31
# fetch_sentinel2():Skipping cloud gap filling; no S2 data prior to 2017-03-28 available in GEE, cannot fill cloud gaps for 2018-01-01-2018-01-31 with previous year of data
# fetch_sentinel2(): bye!
# fetch_sentinel2(): hello!
# fetch_sentinel2(): processing period: 2019-01-01 to 2019-01-31
# fetch_sentinel2(): bye!
